# %% [markdown]
# ##  Modules Tutorial
#
# We'll bring in the module practice.py that we have created and illustrate some of it uses.
#
# We'll start with some basics about dir and help commands in Python

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_2',
#  '_3',
#  '_4',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
import practice

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_1',
#  '_2',
#  '_3',
#  '_4',
#  '_5',
#  '_7',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'practice',
#  'quit']

# %%
dir(practice)
# Out:
# ['Box',
#  'Circle',
#  'Consumer',
#  'Sphere',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'math',
#  'pi']

# %%
help(practice)
# Out:
# Help on module practice:
#
# NAME
#     practice
#
# DESCRIPTION
#     ## This is the practice module
#     ##
#
# CLASSES
#     builtins.object
#         Box
#         Circle
#         Consumer
#         Sphere
#
#     class Box(builtins.object)
#      |  Box(w=1, h=1, l=1)
#      |
#      |  computes volume and surface area of a box of dimensions width, height, length = w, h, l
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, w=1, h=1, l=1)
#      |      Intialize box with width, height, length w, h, l
#      |
#      |  surface(self)
#      |      surface of a box of width, height, length w, h, l
#      |
#      |  volume(self)
#      |      volume of a box of width, height, length w, h, l
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables (if defined)
#      |
#      |  __weakref__
# ...

# %%
help(practice.Consumer)
# Out:
# Help on class Consumer in module practice:
#
# class Consumer(builtins.object)
#  |  Consumer(w)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, w)
#  |      Initialize consumer with w dollars of wealth
#  |
#  |  earn(self, y)
#  |      The consumer earns y dollars
#  |
#  |  spend(self, x)
#  |      The consumer spends x dollars if feasible
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(practice.Circle)
# Out:
# Help on class Circle in module practice:
#
# class Circle(builtins.object)
#  |  Circle(r=1)
#  |
#  |  computes area and circumference of circles of radius r
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, r=1)
#  |      Initialize circle with radius r
#  |
#  |  area(self)
#  |      area of circle of radius r
#  |
#  |  circumference(self)
#  |      circumference of circle of radius r
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
# use the Circle class

c1=practice.Circle(2)

print(c1.area(), c1.circumference())
# Out:
# 12.566370614359172 12.566370614359172

# %%
# import just Circle
from practice import Circle

c1=Circle(2)
help(Circle)
# Out:
# Help on class Circle in module practice:
#
# class Circle(builtins.object)
#  |  Circle(r=1)
#  |
#  |  computes area and circumference of circles of radius r
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, r=1)
#  |      Initialize circle with radius r
#  |
#  |  area(self)
#  |      area of circle of radius r
#  |
#  |  circumference(self)
#  |      circumference of circle of radius r
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
help(Circle.area)
# Out:
# Help on function area in module practice:
#
# area(self)
#     area of circle of radius r

# %%
print(c1.area(),c1.circumference())
# Out:
# 12.566370614359172 12.566370614359172

# %%
from practice import Sphere

# %%
help(Sphere)
# Out:
# Help on class Sphere in module practice:
#
# class Sphere(builtins.object)
#  |  Sphere(r=1)
#  |
#  |  computes volume and surface area of sphere of radius r
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, r=1)
#  |      Initialize sphere with radius r
#  |
#  |  surface(self)
#  |      Surface of a sphere of radius r
#  |
#  |  volume(self)
#  |      Volume of sphere of radius r
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
s1=Sphere(10)
vol1 = s1.volume()
surf1=s1.surface()
print(vol1,surf1)
# Out:
# 4188.790204786391 1256.6370614359173

# %% [markdown]
# ## More modules
#
# math
#
# quantecon

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'pi',
#  'pow',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
help(math.radians)
# Out:
# Help on built-in function radians in module math:
#
# radians(x, /)
#     Convert angle x from degrees to radians.

# %%
math.radians(90)
# Out:
# 1.5707963267948966

# %%
import quantecon as qe
help(qe)
# Out:
# Help on package quantecon:
#
# NAME
#     quantecon - Import the main names to top level.
#
# PACKAGE CONTENTS
#     arma
#     ce_util
#     compute_fp
#     discrete_rv
#     distributions
#     dle
#     ecdf
#     estspec
#     filter
#     game_theory (package)
#     graph_tools
#     gridtools
#     inequality
#     ivp
#     kalman
#     lae
#     lqcontrol
#     lqnash
#     lss
#     markov (package)
#     matrix_eqn
#     optimize (package)
#     quad
#     quadsums
#     random (package)
#     rank_nullspace
#     robustlq
#     tests (package)
#     util (package)
#     version
#
# VERSION
#     0.4.7
#
# FILE
#     /Users/tom/anaconda3/lib/python3.7/site-packages/quantecon/__init__.py

# %%
help(qe.lss)
# Out:
# Help on module quantecon.lss in quantecon:
#
# NAME
#     quantecon.lss - Computes quantities associated with the Gaussian linear state space model.
#
# DESCRIPTION
#     References
#     ----------
#
#     https://lectures.quantecon.org/py/linear_models.html
#
# CLASSES
#     builtins.object
#         LinearStateSpace
#
#     class LinearStateSpace(builtins.object)
#      |  LinearStateSpace(A, C, G, H=None, mu_0=None, Sigma_0=None)
#      |
#      |  A class that describes a Gaussian linear state space model of the
#      |  form:
#      |
#      |  .. math::
#      |
#      |    x_{t+1} = A x_t + C w_{t+1}
#      |
#      |    y_t = G x_t + H v_t
#      |
#      |  where :math:`{w_t}` and :math:`{v_t}` are independent and standard normal
#      |  with dimensions k and l respectively.  The initial conditions are
#      |  :math:`\mu_0` and :math:`\Sigma_0` for :math:`x_0 \sim N(\mu_0, \Sigma_0)`.
#      |  When :math:`\Sigma_0=0`, the draw of :math:`x_0` is exactly :math:`\mu_0`.
# ...
